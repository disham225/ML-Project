# %% [markdown]
# # **Project Name**    - **Email Campaign ML Project**

# %% [markdown]
# ##### **Project Type**    - Classification
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Project Summary: Predicting Email Campaign Effectiveness Using Machine Learning
# In the ever-evolving digital marketing landscape, email campaigns play a pivotal role in customer engagement, retention, and conversion. However, the effectiveness of these campaigns is often challenged by varying customer responses, necessitating a data-driven approach to optimize outcomes. This project aimed to predict the effectiveness of email campaigns using machine learning techniques, offering valuable insights that can enhance campaign strategies, improve customer targeting, and ultimately drive business growth.
#
# Objective
#
# The primary objective of this project was to build a predictive model capable of determining the likelihood of an email being successful, as defined by customer engagement metrics. Success was measured by the Email_Status variable, which indicated whether a customer interacted positively with the email. By leveraging machine learning, the goal was to identify patterns in the dataset that could predict this outcome, allowing for more informed decision-making in future campaigns.
#
# Dataset Overview
#
# The dataset comprised 68,353 rows and 12 primary columns, each representing various attributes related to the email campaigns and customer characteristics. Key features included Subject_Hotness_Score, Total_Past_Communications, Time_Email_sent_Category, Word_Count, Total_Links, Total_Images, and Email_Status. Additionally, the dataset included binary-encoded categorical variables such as Customer_Location_B, Customer_Location_C, and others, along with Email_Length_Category and Email_Type.
#
# The dataset posed challenges, including missing values in key columns like Customer_Location, Total_Past_Communications, Total_Links, and Total_Images. These missing values were imputed using statistical methods, ensuring the dataset was robust enough for model training.
#
# Methodology
#
# The project employed three machine learning models: Logistic Regression, Gradient Boosting Classifier, and Support Vector Machine (SVM). These models were chosen for their varying strengths in classification tasks, enabling a comparative analysis to identify the most effective approach.
#
# Model 1: Logistic Regression
# Logistic Regression was used as the baseline model due to its simplicity and interpretability. It provided a clear understanding of how each feature contributed to the prediction of email effectiveness. The model was evaluated using standard metrics such as accuracy, precision, recall, F1 score, and ROC AUC. The initial results were promising, with balanced performance across all metrics.
#
# Model 2: Gradient Boosting Classifier
# The Gradient Boosting Classifier was selected for its ability to handle complex, non-linear relationships in the data. This model showed improved performance over Logistic Regression, particularly in recall and ROC AUC, which are critical in identifying successful email campaigns. Cross-validation and hyperparameter tuning were performed using GridSearchCV, leading to further improvements in model accuracy and robustness.
#
# Model 3: Support Vector Machine (SVM)
# SVM was used for its strength in high-dimensional spaces and its effectiveness in scenarios where classes are not linearly separable. Despite its theoretical advantages, the model's training time was significantly longer, especially during hyperparameter tuning with RandomizedSearchCV. Ultimately, the performance gains did not justify the computational cost, making it less practical for large-scale application.
#
# Results and Insights
#
# After thorough evaluation, the Gradient Boosting Classifier emerged as the most suitable model for this task. It provided the best balance between precision and recall, essential for minimizing false positives and negatives in email campaign predictions. The ROC AUC score further confirmed its ability to distinguish between successful and unsuccessful campaigns effectively.
#
# To understand the business implications of these models, SHAP (SHapley Additive exPlanations) was initially considered for feature importance analysis. However, due to compatibility issues with multiclass classification in Gradient Boosting, alternative tools like Eli5 were explored. Eli5 provided clear visualizations of feature importance, highlighting key drivers such as Subject_Hotness_Score and Total_Past_Communications.
#
# Conclusion
#
# This project demonstrated the power of machine learning in predicting email campaign effectiveness, offering a data-driven approach to optimize marketing strategies. By selecting the Gradient Boosting Classifier as the final model, the project provided a robust tool for improving customer engagement and maximizing the return on investment for email campaigns. The insights gained from feature importance analysis can guide future campaign designs, ensuring they resonate more effectively with the target audience. Moving forward, integrating this model into a real-time marketing system could further enhance its impact, enabling dynamic, responsive campaign adjustments based on predictive analytics.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# In today’s digital marketing landscape, email campaigns play a crucial role in engaging customers and driving business growth. However, the effectiveness of these campaigns often hinges on whether recipients open and interact with the emails. With vast amounts of data generated from these campaigns, businesses face the challenge of accurately predicting the likelihood of an email being opened, which is a critical indicator of campaign success.
#
# The problem this project aims to address is to predict the "Email_Status" (opened or not opened) of email campaigns based on various features such as subject hotness score, total past communications, time of email sent, word count, number of links and images, email type, source type, campaign type, customer location, and email length category. Accurate predictions will enable businesses to optimize their email campaigns, target the right audience more effectively, and ultimately improve customer engagement and conversion rates.
#
# This project involves building and evaluating multiple machine learning models to identify the best-performing model for this classification task. The objective is to develop a robust predictive model that can be deployed to enhance the strategic decision-making process in email marketing efforts.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

# Data Manipulation
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
from scipy import stats
from sklearn.impute import SimpleImputer
from scipy.stats import zscore
from sklearn.preprocessing import OneHotEncoder
import contractions
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import PowerTransformer
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC










# Set up the visualization style
sns.set(style='whitegrid')
plt.style.use('fivethirtyeight')

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

data = pd.read_csv('/content/data_email_campaign.csv')
df = data.copy()

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#             Email_ID  Email_Type  Subject_Hotness_Score  Email_Source_Type  \
# 0  EMA00081000034500           1                    2.2                  2
# 1  EMA00081000045360           2                    2.1                  1
# 2  EMA00081000066290           2                    0.1                  1
# 3  EMA00081000076560           1                    3.0                  2
# 4  EMA00081000109720           1                    0.0                  2
#
#   Customer_Location  Email_Campaign_Type  Total_Past_Communications  \
# 0                 E                    2                       33.0
# 1               NaN                    2                       15.0
# 2                 B                    3                       36.0
# 3                 E                    2                       25.0
# 4                 C                    3                       18.0
#
#    Time_Email_sent_Category  Word_Count  Total_Links  Total_Images  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (68353, 12)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68353 entries, 0 to 68352
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Email_ID                   68353 non-null  object
#  1   Email_Type                 68353 non-null  int64
#  2   Subject_Hotness_Score      68353 non-null  float64
#  3   Email_Source_Type          68353 non-null  int64
#  4   Customer_Location          56758 non-null  object
#  5   Email_Campaign_Type        68353 non-null  int64
#  6   Total_Past_Communications  61528 non-null  float64
#  7   Time_Email_sent_Category   68353 non-null  int64
#  8   Word_Count                 68353 non-null  int64
#  9   Total_Links                66152 non-null  float64
#  10  Total_Images               66676 non-null  float64
#  11  Email_Status               68353 non-null  int64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 6.3+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# Email_ID                         0
# Email_Type                       0
# Subject_Hotness_Score            0
# Email_Source_Type                0
# Customer_Location            11595
# Email_Campaign_Type              0
# Total_Past_Communications     6825
# Time_Email_sent_Category         0
# Word_Count                       0
# Total_Links                   2201
# Total_Images                  1677
# Email_Status                     0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * The dataset comprises 68,353 rows and 12 columns, with no duplicate rows present, ensuring its cleanliness. Each row represents an email, uniquely identified by the Email_ID column. The dataset includes various features such as Email_Type, Subject_Hotness_Score, Email_Source_Type, Customer_Location, Email_Campaign_Type, Total_Past_Communications, Time_Email_sent_Category, Word_Count, Total_Links, Total_Images, and Email_Status.
#
# * There are missing values in four columns: Customer_Location (11,595 missing values), Total_Past_Communications (6,825 missing values), Total_Links (2,201 missing values), and Total_Images (1,677 missing values). Despite these gaps, the dataset remains robust for analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Email_ID', 'Email_Type', 'Subject_Hotness_Score', 'Email_Source_Type',
#        'Customer_Location', 'Email_Campaign_Type', 'Total_Past_Communications',
#        'Time_Email_sent_Category', 'Word_Count', 'Total_Links', 'Total_Images',
#        'Email_Status'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#          Email_Type  Subject_Hotness_Score  Email_Source_Type  \
# count  68353.000000           68353.000000       68353.000000
# mean       1.285094               1.095481           1.456513
# std        0.451462               0.997578           0.498109
# min        1.000000               0.000000           1.000000
# 25%        1.000000               0.200000           1.000000
# 50%        1.000000               0.800000           1.000000
# 75%        2.000000               1.800000           2.000000
# max        2.000000               5.000000           2.000000
#
#        Email_Campaign_Type  Total_Past_Communications  \
# count         68353.000000               61528.000000
# mean              2.272234                  28.933250
# std               0.468680                  12.536518
# min               1.000000                   0.000000
# 25%               2.000000                  20.000000
# 50%               2.000000                  28.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Here's a gentle overview of each variable in the dataset, explaining their significance and how they contribute to predicting email campaign effectiveness:
#
# **Email_Type**
#
# Description: This variable categorizes the type of email sent. The types are encoded as numerical values (1 or 2).
#
# Role: Different types of emails might have varying levels of engagement from recipients.
#
# **Subject_Hotness_Score**
#
# Description: A score indicating how attractive or interesting the subject line of the email is, ranging from 0 to 5.
#
# Role: A higher score could correlate with higher email engagement.
#
# **Email_Source_Type**
#
# Description: The source type of the email, encoded as numerical values (1 or 2).
#
# Role: The origin of the email might influence how recipients perceive and interact with it.
#
# **Email_Campaign_Type**
#
# Description: The type of campaign the email is part of, with values ranging from 1 to 3.
#
# Role: Different campaign types might have different success rates.
#
# **Total_Past_Communications**
#
# Description: The total number of past communications with the customer.
#
# Role: A higher number of past interactions might indicate a stronger relationship and potentially higher engagement.
#
# **Time_Email_sent_Category**
#
# Description: The category indicating the time the email was sent, with values ranging from 1 to 3.
#
# Role: The timing of the email can significantly impact its effectiveness.
#
# **Word_Count**
#
# Description: The total number of words in the email.
#
# Role: The length of the email might affect readability and engagement.
#
# **Total_Links**
#
# Description: The total number of links included in the email.
#
# Role: More links might provide more opportunities for engagement, but too many could be overwhelming.
#
# **Total_Images**
#
# Description: The total number of images included in the email.
#
# Role: Images can make emails more visually appealing but can also impact loading time and accessibility.
#
# **Email_Status**
#
# Description: The status of the email, indicating whether it was ignored, read, or acknowledged by the recipient, with values ranging from 0 to 2.
#
# Role: This is the target variable we aim to predict. Understanding what influences email status can help optimize future campaigns.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in df.columns:
    print(f"{col}: {df[col].unique()}")
# Out:
# Email_ID: ['EMA00081000034500' 'EMA00081000045360' 'EMA00081000066290' ...
#  'EMA00089998436500' 'EMA00089999168800' 'EMA00089999316900']
# Email_Type: [1 2]
# Subject_Hotness_Score: [2.2 2.1 0.1 3.  0.  1.5 3.2 0.7 2.  0.5 0.2 1.  4.  1.9 1.1 1.6 0.3 2.3
#  1.4 1.7 2.8 1.2 0.8 0.6 4.2 1.8 2.4 0.9 1.3 3.3 2.6 3.1 4.1 2.9 2.7 0.4
#  3.5 3.7 2.5 3.8 3.9 3.4 4.6 4.5 3.6 4.4 4.7 5.  4.3 4.8 4.9]
# Email_Source_Type: [2 1]
# Customer_Location: ['E' nan 'B' 'C' 'G' 'D' 'F' 'A']
# Email_Campaign_Type: [2 3 1]
# Total_Past_Communications: [33. 15. 36. 25. 18. nan 34. 21. 40. 27. 24. 42. 11. 23. 37. 35. 51.  9.
#  39. 31. 50. 30. 14. 45. 53. 28.  7. 38. 52. 22. 43. 12. 16. 20. 41. 56.
#  26. 29.  5. 32. 44. 10. 17. 46. 47. 48.  8. 49. 13.  0.  6. 55. 19. 60.
#  59. 61. 54. 62. 57. 64. 58. 65. 66. 67. 63.]
# Time_Email_sent_Category: [1 2 3]
# Word_Count: [ 440  504  962  610  947  416  116 1241  655  744  931  550  565  700
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Display the first few rows
print("Initial Data:")
print(df.head())

# Display dataset information
print("\nData Info:")
print(df.info())

# Check for duplicates
print("\nDuplicate Rows:")
print(f'Duplicate rows: {df.duplicated().sum()}')

# Check for missing values
print("\nMissing Values Info:")
print(df.isnull().sum())
# Out:
# Initial Data:
#             Email_ID  Email_Type  Subject_Hotness_Score  Email_Source_Type  \
# 0  EMA00081000034500           1                    2.2                  2
# 1  EMA00081000045360           2                    2.1                  1
# 2  EMA00081000066290           2                    0.1                  1
# 3  EMA00081000076560           1                    3.0                  2
# 4  EMA00081000109720           1                    0.0                  2
#
#   Customer_Location  Email_Campaign_Type  Total_Past_Communications  \
# 0                 E                    2                       33.0
# 1               NaN                    2                       15.0
# 2                 B                    3                       36.0
# 3                 E                    2                       25.0
# 4                 C                    3                       18.0
#
#    Time_Email_sent_Category  Word_Count  Total_Links  Total_Images  \
# ...

# %%
# Handle missing values for numerical columns
numerical_cols = ['Total_Past_Communications', 'Total_Links', 'Total_Images']
numerical_imputer = SimpleImputer(strategy='mean')
df[numerical_cols] = numerical_imputer.fit_transform(df[numerical_cols])

# Handle missing values for categorical columns
categorical_cols = ['Customer_Location']
categorical_imputer = SimpleImputer(strategy='most_frequent')
df[categorical_cols] = categorical_imputer.fit_transform(df[categorical_cols])

# %%
# Convert categorical variables to 'category' dtype
df['Email_Type'] = df['Email_Type'].astype('category')
df['Email_Source_Type'] = df['Email_Source_Type'].astype('category')
df['Email_Campaign_Type'] = df['Email_Campaign_Type'].astype('category')
df['Time_Email_sent_Category'] = df['Time_Email_sent_Category'].astype('category')

# %%
# Create a new feature for email length category
df['Email_Length_Category'] = pd.cut(df['Word_Count'], bins=[0, 100, 500, 1000, 5000], labels=['Short', 'Medium', 'Long', 'Very Long'])

# Convert 'Email_Length_Category' to a categorical variable
df['Email_Length_Category'] = df['Email_Length_Category'].astype('category')

# Encode categorical variables using one-hot encoding
df = pd.get_dummies(df, columns=['Customer_Location', 'Email_Length_Category'], drop_first=True)

# drop Email column
df.drop('Email_ID', axis=1, inplace=True)


# Define feature columns and target variable
X = df.drop('Email_Status', axis=1)
y = df['Email_Status']

# Display the shapes of X and y
print("\nFeature and Target Shapes:")
print(f'Features shape: {X.shape}')
print(f'Target shape: {y.shape}')

# Display the first few rows of the processed data
print("\nProcessed Data:")
print(X.head())
# Out:
# Feature and Target Shapes:
# Features shape: (68353, 18)
# Target shape: (68353,)
#
# Processed Data:
#   Email_Type  Subject_Hotness_Score Email_Source_Type Email_Campaign_Type  \
# 0          1                    2.2                 2                   2
# 1          2                    2.1                 1                   2
# 2          2                    0.1                 1                   3
# 3          1                    3.0                 2                   2
# 4          1                    0.0                 2                   3
#
#    Total_Past_Communications Time_Email_sent_Category  Word_Count  \
# 0                       33.0                        1         440
# 1                       15.0                        2         504
# 2                       36.0                        2         962
# 3                       25.0                        2         610
# 4                       18.0                        2         947
#
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?
#
# ---
#
#
#
# 1. Loaded the Dataset
# Action: Imported the dataset to examine its structure and initial content.
# Insight: The dataset consists of 68,353 rows and 12 columns, containing both categorical and numerical data.
# 2. Checked for Duplicates and Missing Values
# Action: Identified if there were any duplicate rows and checked for missing values in the dataset.
# Insight: No duplicate rows were found. Missing values were identified in several columns, which could affect the accuracy of the analysis and model performance.
# 3. Handled Missing Values
# Action: Filled missing values to ensure data completeness. For categorical variables (Customer_Location), missing values were filled with the most frequent value (mode). For numerical variables (Total_Past_Communications, Total_Links, Total_Images), missing values were replaced with the mean.
# Insight: Addressing missing values ensures that the dataset is complete and ready for accurate analysis and modeling.
# 4. Converted Data Types
# Action: Converted certain integer columns to categorical types to better reflect their nature as categorical data.
# Insight: This conversion helps in correctly processing these variables in subsequent analyses and model training.
# 5. Created Derived Features
# Action: Introduced a new feature, Email_Length_Category, to categorize emails based on their word count into categories like Short, Medium, Long, and Very Long.
# Insight: This new feature allows for deeper analysis of how the length of emails might influence engagement and effectiveness.
# 6. Encoded Categorical Variables
# Action: Applied one-hot encoding to categorical variables, including Customer_Location and the newly created Email_Length_Category.
# Insight: This encoding transforms categorical data into a numerical format suitable for machine learning models, ensuring that the models can effectively use these variables.
# 7. Dropped Unnecessary Columns
# Action: Removed the Email_ID column, which was an identifier and not useful for analysis or modeling.
# Insight: Simplifies the dataset by focusing only on relevant features, making it easier to manage and analyze.
# 8. Prepared Data for Modeling
# Action: Separated the features (X) and the target variable (Email_Status) for use in model training.
# Insight: The dataset is now structured for machine learning, with clearly defined features and target variables ready for analysis.

# %% [markdown]
# Load Data: Reads the dataset into a DataFrame.
# Initial Checks: Displays the first few rows, information about data types, duplicates, and missing values.
# Handle Missing Values: Imputes missing values for categorical and numerical columns.
# Convert Data Types: Converts relevant columns to categorical types.
# Feature Engineering: Creates a new feature based on Word_Count.
# Encode Categorical Variables: Applies one-hot encoding to categorical columns.
# Drop Unnecessary Columns: Removes the Email_ID column as it is not needed.
# Prepare Data for Modeling: Separates features and the target variable, and displays the shapes of the processed data.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Email_Type')
plt.title('Distribution of Email Types')
plt.xlabel('Email Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A count plot is used to visualize the frequency of each email type in the dataset, helping to understand the distribution of email types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Email Type Distribution: The chart shows that there are two types of emails with a significant disparity in their distribution. Email Type 1 constitutes a larger portion of the emails (48,866 emails), whereas Email Type 2 makes up a smaller portion (19,487 emails).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Impact: Understanding the distribution of email types can help in strategizing future email campaigns. If Email_Type 1 is more effective or has a higher engagement rate, the business can focus more on this type of email to maximize returns.
#
# * Negative Growth: If Email_Type 2 is underperforming, it could be due to factors such as less appealing content, timing, or target audience mismatch. Identifying and addressing these issues can prevent negative growth. However, if not investigated and rectified, continuously sending underperforming email types could lead to lower engagement rates and potentially harm the brand's reputation.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(8, 6))
sns.histplot(df['Subject_Hotness_Score'], bins=30, kde=True)
plt.title('Distribution of Subject Hotness Score')
plt.xlabel('Subject Hotness Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A histogram with a KDE (Kernel Density Estimate) overlay provides a clear view of the distribution of continuous numerical data, such as the

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The Subject_Hotness_Score ranges from 0 to 5, with an average score of approximately 1.1. The median score is 0.8, indicating that more than half of the emails have a subject hotness score of less than 1. The distribution is right-skewed, with most scores clustered at the lower end and a few high outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Impact: Understanding the distribution of Subject_Hotness_Score can help in tailoring subject lines to improve engagement. By analyzing the characteristics of emails with higher scores, businesses can craft more compelling subject lines, potentially increasing open rates and customer engagement.
# * Negative Growth: If most emails have a low Subject_Hotness_Score, it could indicate that the subject lines are not engaging enough. Without addressing this, the business may continue to experience low engagement rates. This could lead to reduced effectiveness of email campaigns and potentially lower customer interest over time.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Email_Source_Type')
plt.title('Distribution of Email Source Types')
plt.xlabel('Email Source Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A countplot effectively shows the distribution of categories within a categorical variable, making it ideal for visualizing the Email_Source_Type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The distribution of Email_Source_Type indicates that the two types of email sources are fairly balanced. Email_Source_Type 1 is slightly more prevalent, with 37,149 emails, compared to 31,204 emails for Email_Source_Type 2. This suggests that both sources are used significantly in the campaign, but with a slight preference for one over the other.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Impact: Knowing the distribution of email sources can help in optimizing marketing strategies. If Email_Source_Type 1 is more effective in engaging recipients or achieving desired outcomes, businesses might allocate more resources or focus on this source to enhance campaign performance.
# * Negative Growth: If one email source underperforms, it could be due to factors such as less effective targeting or content. This imbalance could lead to inefficient use of resources. Analyzing the performance of each source can help in adjusting strategies to ensure both sources are optimized for better results.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Email_Campaign_Type')
plt.title('Distribution of Email Campaign Types')
plt.xlabel('Email Campaign Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A countplot is suitable for visualizing the frequency of different categories in the Email_Campaign_Type column, enabling easy comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The distribution shows that Email_Campaign_Type 2 is the most prevalent, with 48,273 emails. This is followed by Email_Campaign_Type 3 with 19,344 emails, and Email_Campaign_Type 1, which has a significantly lower count of 736 emails. This indicates a strong preference or higher usage of Email_Campaign_Type 2 in the email campaigns.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Impact: Understanding the distribution of email campaign types can inform future campaign strategies. If Email_Campaign_Type 2 is more successful or effective, businesses can allocate more resources to this type or analyze its characteristics to replicate its success in other campaigns.
# * Negative Growth: If Email_Campaign_Type 1 is underperforming or has a significantly lower count, it could be due to less effective strategies or less compelling content. This could result in wasted resources and missed opportunities. Identifying the reasons for its low usage and addressing them can prevent negative impacts on campaign performance.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(8, 6))
sns.histplot(df['Total_Past_Communications'], bins=30, kde=True)
plt.title('Distribution of Total Past Communications')
plt.xlabel('Total Past Communications')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A histogram with a KDE overlay is useful for visualizing the distribution of continuous numerical data, such as Total_Past_Communications.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The Total_Past_Communications variable shows a wide range, from 0 to 67, with an average of approximately 28.93. Most emails have between 20 and 38 past communications, as indicated by the 25th and 75th percentiles. The median value is 28, suggesting that a significant number of recipients have a moderate history of communications.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Impact: Understanding the distribution of past communications can help in tailoring email strategies. For example, emails to recipients with a higher number of past communications might require different messaging or offers compared to those with fewer past interactions. This can enhance targeting and personalization, leading to improved engagement and conversion rates.
# * Negative Growth: If emails are sent to recipients with extremely high or low past communications without considering this factor, it could lead to ineffective campaigns. For instance, recipients with very high past communications might feel overwhelmed or annoyed if they receive too many emails, while those with low past communications might not feel valued or engaged.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(8, 6))
sns.histplot(df['Word_Count'], bins=30, kde=True)
plt.title('Distribution of Word Count')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A histogram with a KDE overlay provides a clear view of the distribution of continuous numerical data, such as the Word_Count.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The Word_Count variable has a wide range, from 40 to 1316 words, with an average of approximately 699.93. The median word count is 694, and the 25th and 75th percentiles are 521 and 880, respectively. This indicates that most emails have a word count between 521 and 880 words, with a few having significantly higher or lower counts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Impact: Understanding the distribution of word counts can help optimize email content. For instance, analyzing the performance of emails with different word counts can reveal whether shorter or longer emails are more effective. This allows for crafting email content that aligns with recipient preferences and improves engagement.
# * Negative Growth: If emails have word counts that are either too high or too low, it could affect engagement negatively. For example, very long emails might overwhelm recipients, while very short emails might lack sufficient detail to be compelling. Balancing word count to suit recipient preferences can prevent negative impacts on engagement.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(8, 6))
sns.histplot(df['Total_Links'], bins=30, kde=True)
plt.title('Distribution of Total Links')
plt.xlabel('Total Links')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A histogram with a KDE overlay is suitable for visualizing the distribution of continuous numerical data, such as the Total_Links.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The Total_Links variable ranges from 1 to 49, with an average of approximately 10.43 links per email. The median is 9, and the 25th and 75th percentiles are 6 and 14, respectively. This indicates that most emails contain between 6 and 14 links, with a few containing significantly more.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Impact: Understanding the distribution of total links can help in optimizing email content. If emails with a moderate number of links perform better, this insight can guide the inclusion of links in future emails to balance engagement and avoid overwhelming recipients with too many links.
# * Negative Growth: Emails with either too few or too many links might be less effective. Too few links could limit opportunities for recipients to engage with the content, while too many links might clutter the email or reduce its effectiveness. Analyzing the performance of emails with varying link counts can help in finding the optimal number of links.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
plt.figure(figsize=(8, 6))
sns.histplot(df['Total_Images'], bins=30, kde=True)
plt.title('Distribution of Total Images')
plt.xlabel('Total Images')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A histogram with a KDE overlay provides a clear view of the distribution of continuous numerical data, such as the Total_Images.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The Total_Images variable ranges from 0 to 45, with an average of approximately 3.55 images per email. The median is 0, and the 25th and 75th percentiles are also 0 and 5, respectively. This indicates that a significant number of emails have no images, and most of those that do have a relatively small number of images, with some emails containing up to 45 images.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Impact: Understanding the distribution of images can help in designing visually appealing emails without overwhelming recipients. If emails with a moderate number of images perform better, businesses can use this insight to balance the visual content in future emails to enhance engagement and effectiveness.
# * Negative Growth: Emails with too few or too many images might affect engagement negatively. Emails with no images might be less engaging, while those with an excessive number of images could be perceived as cluttered or distracting. Optimizing the number of images based on performance data can prevent negative outcomes and improve email effectiveness.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Email_Status')
plt.title('Distribution of Email Status')
plt.xlabel('Email Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A countplot is ideal for visualizing the frequency of categorical data, making it perfect for showing the distribution of Email_Status.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The Email_Status variable indicates the outcome of the emails, with most emails (54,941) categorized as status 0. A smaller number are categorized as status 1 (11,039) and even fewer as status 2 (2,373). This suggests that the majority of emails have a status of 0, indicating a specific outcome or lack of engagement, while fewer emails fall into the other statuses.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Impact: Understanding the distribution of Email_Status can help in evaluating the effectiveness of different email campaigns or strategies. If status 0 represents non-engagement or an undesired outcome, analyzing why this is the most common status can inform strategies to improve engagement and conversion rates.
# * Negative Growth: If status 0 represents negative outcomes (e.g., ignored or not opened emails), the high count could indicate issues with email content, timing, or targeting. Addressing these issues can prevent negative impacts and improve overall campaign performance.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Email_Status', y='Subject_Hotness_Score')
plt.title('Email Status vs Subject Hotness Score')
plt.xlabel('Email Status')
plt.ylabel('Subject Hotness Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A boxplot is useful for comparing the distribution of a numerical variable across different categories, making it ideal for visualizing Subject_Hotness_Score against Email_Status.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The Subject_Hotness_Score ranges from 0 to 5, with an average score of approximately 1.10. The median score is 0.80, with 25th and 75th percentiles at 0.20 and 1.80, respectively. This indicates that most emails have a relatively low subject hotness score, with very few reaching higher scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Impact: Knowing the distribution of subject hotness scores can help in crafting more engaging email subject lines. If emails with higher hotness scores tend to perform better, businesses can focus on improving subject lines to increase engagement and open rates.
# * Negative Growth: If a significant number of emails have very low hotness scores, it could indicate issues with how subject lines are being created. Low scores might correlate with lower engagement or open rates, and not addressing this could negatively impact campaign performance.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Email_Status', y='Total_Past_Communications')
plt.title('Email Status vs Total Past Communications')
plt.xlabel('Email Status')
plt.ylabel('Total Past Communications')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A boxplot is effective for comparing the distribution of a numerical variable across categories, making it ideal for visualizing Total_Past_Communications against Email_Status.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The Total_Past_Communications varies significantly across different Email_Status categories.
# For Email_Status 0, the average number of past communications is about 27.40, with a standard deviation of 11.62.
# For Email_Status 1, the average is higher at 34.71, with a standard deviation of 13.98.
# For Email_Status 2, the average is the highest at 37.60, with a standard deviation of 14.36.
# Emails with Email_Status 2 tend to have a higher number of past communications compared to those with statuses 0 and 1.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Impact: The insights indicate that a higher number of past communications is associated with higher email statuses, which could imply that recipients with more past interactions are more likely to engage positively with emails. Understanding this relationship can help in targeting and personalizing future emails to recipients with varying levels of past communications, potentially improving engagement and conversion rates.
# * Negative Growth: If the relationship suggests that high past communications correlate with negative outcomes (e.g., status 0), it could imply that over-communication might lead to reduced engagement. This could be due to recipients becoming disengaged or overwhelmed by frequent emails.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
plt.figure(figsize=(8, 6))
email_length_cols = ['Email_Length_Category_Medium', 'Email_Length_Category_Long', 'Email_Length_Category_Very Long']
df[email_length_cols].sum().plot(kind='bar')
plt.title('Distribution of Email Length Categories')
plt.xlabel('Email Length Category')
plt.ylabel('Count')
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Countplots are effective for visualizing the distribution of categorical data, making them suitable for showing the distribution of Email_Length_Category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Email Length Distribution: Long emails are most prevalent (43,236), followed by medium (14,247) and very long emails (9,835), indicating a trend towards longer email formats in the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Impact: Knowing the distribution of email lengths helps in tailoring email strategies. If long emails are common and effective, focusing on optimizing their content could enhance engagement. Conversely, if medium-length emails show better performance, adjusting strategies to favor this length could improve results.
# * Potential Negative Impact: Over-reliance on very long emails, which are less common, might lead to diminishing returns if they do not engage readers as effectively as shorter or medium-length emails. Evaluating their performance carefully is essential to avoid potential negative impacts on engagement.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
plt.figure(figsize=(8, 6))
email_length_cols = ['Email_Length_Category_Medium', 'Email_Length_Category_Long', 'Email_Length_Category_Very Long']
df[email_length_cols].sum().plot(kind='bar')
plt.title('Distribution of Email Length Categories')
plt.xlabel('Email Length Category')
plt.ylabel('Count')
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Countplots are effective for visualizing the distribution of categorical data, making them suitable for showing the distribution of Email_Length_Category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Email Length Distribution: Long emails dominate the dataset (43,236), with medium-length emails (14,247) and very long emails (9,835) being less frequent.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Business Impact:Understanding that "Long" emails are the most common category can help businesses optimize their email strategies. By focusing on crafting high-quality, engaging content for these longer emails, companies can potentially improve open rates and conversions, aligning their content with the preferences of their audience.
#
# * Negative Impact:If longer emails show lower engagement compared to shorter ones, this could indicate that lengthy content might not be resonating with recipients. This could lead to decreased effectiveness of email campaigns and lower customer engagement, highlighting the need to reassess the email content strategy.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr(numeric_only=True)

# Set up the matplotlib figure
plt.figure(figsize=(14, 12))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5,
    vmin=-1,  # Ensures that the color scale is symmetric
    vmax=1,
    square=True,
    cbar_kws={"shrink": 0.8}  # Adjust color bar size
)

# Add titles and labels
plt.title('Correlation Heatmap', size=16, weight='bold')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A heatmap is ideal for visualizing correlations between multiple variables, providing a comprehensive view of their relationships.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Email_Type Distribution: Email_Type 1 is most common; focusing on this type can optimize strategies.
#
# * Subject_Hotness_Score: Many emails have a low score, suggesting a need to improve subject lines.
#
# * Email_Source_Type: Almost evenly distributed; balanced source use can enhance effectiveness.
#
# * Email_Campaign_Type: Email_Campaign_Type 2 dominates; exploring type 1 could uncover new opportunities.
#
# * Total_Past_Communications: Most emails fall within the 20-38 range; adjust communication frequency accordingly.
#
# * Word_Count: Varies greatly; optimizing word count can improve email effectiveness.
#
# * Total_Links: High variability; balancing links might affect engagement.
#
# * Total_Images: Many emails have few or no images; consider using more images for better engagement.
#
# * Email_Status: Most emails have low engagement; identifying improvement factors is crucial.
#
# * Customer_Location: Weak correlation with other variables; location-based segmentation might be less impactful.
#
# * Email_Type and Email_Status: Weak correlation; Email_Type alone may not predict engagement effectively.
#
# * Subject_Hotness_Score and Email_Status: Negative correlation; revisit hotness scoring criteria.
#
# * Email_Campaign_Type and Total_Past_Communications: Positive correlation; campaign types linked with communication history.
#
# * Word_Count and Total_Links: Strong positive correlation; balance word count with links for better results.
#
# * Total_Links and Total_Images: High positive correlation; balance between links and images for engagement.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
key_features = df[['Subject_Hotness_Score', 'Total_Past_Communications', 'Word_Count', 'Total_Links', 'Total_Images', 'Email_Status']]
sns.pairplot(key_features, hue='Email_Status')
plt.title('Pair Plot of Key Features')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A pair plot provides a grid of scatter plots and histograms, showing relationships between pairs of numerical variables and distributions, making it ideal for exploring multiple variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Subject_Hotness_Score:**
#
# Insight: The scores range widely, with a mean of 1.10 and a maximum of 5.0.
# Implication: Many emails have lower hotness scores, suggesting that improving subject lines could enhance engagement.
#
# **Total_Past_Communications:**
#
# Insight: Most values cluster between 20 and 38, with a mean of 28.93.
# Implication: Communication frequency is generally moderate; adjusting this may impact engagement positively.
#
# **Word_Count:**
#
# Insight: Word counts range from 40 to 1316, with a mean of 699.93.
# Implication: Emails with extremely high or low word counts might affect engagement; finding an optimal range could improve results.
#
# **Total_Links:**
#
# Insight: Most emails have between 6 and 14 links, averaging 10.43.
# Implication: Balancing the number of links might help in better managing user engagement.
#
# **Total_Images:**
#
# Insight: Image counts range from 0 to 45, with a mean of 3.55.
# Implication: Many emails have few or no images; increasing the use of images could enhance visual appeal and engagement.
#
# **Email_Status:**
#
# Insight: Most emails have an Email_Status of 0, indicating low engagement.
# Implication: Identifying and addressing factors leading to low engagement is critical for improving email performance.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Hypothetical Statement - 1
# Statement: The Subject_Hotness_Score varies significantly across different Email_Campaign_Type categories.
#
# Hypothetical Statement - 2
# Statement: There is a significant correlation between the Total_Links and Total_Images in the emails.
#
# Hypothetical Statement - 3
# Statement: The average Word_Count is different for emails with Email_Status 0 compared to those with Email_Status 1

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# * Null Hypothesis (H0): There is no significant difference in Subject_Hotness_Score between emails sent at different times of the day (i.e., Time_Email_sent_Category).
# * Alternate Hypothesis (H1): There is a significant difference in Subject_Hotness_Score between emails sent at different times of the day.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
# Group by 'Time_Email_sent_Category' and collect 'Subject_Hotness_Score'
grouped_scores = [group['Subject_Hotness_Score'] for name, group in df.groupby('Time_Email_sent_Category')]

# Perform ANOVA test
f_stat, p_value = stats.f_oneway(*grouped_scores)
print(f'F-Statistic: {f_stat}, P-Value: {p_value}')
# Out:
# F-Statistic: 4.008448986155335, P-Value: 0.01816581177583107

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# * We performed an ANOVA (Analysis of Variance) test to compare the means of Subject_Hotness_Score across different categories of Time_Email_sent_Category.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# * ANOVA is used when comparing means across multiple groups. Here, it helps determine if there is a significant difference in Subject_Hotness_Score across different times of the day.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# * Null Hypothesis (H0): The Total_Links and Total_Images are independent of each other (i.e., there is no significant correlation between them).
# * Alternate Hypothesis (H1): The Total_Links and Total_Images are not independent of each other (i.e., there is a significant correlation between them).

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
# Perform Pearson correlation test
correlation, p_value = stats.pearsonr(df['Total_Links'].dropna(), df['Total_Images'].dropna())
print(f'Correlation: {correlation}, P-Value: {p_value}')
# Out:
# Correlation: 0.7569844269572473, P-Value: 0.0

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# * We performed a Pearson correlation test to assess the linear relationship between Total_Links and Total_Images

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# * Pearson correlation is appropriate for evaluating the strength and direction of a linear relationship between two continuous variables.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# * Null Hypothesis (H0): The average Word_Count is the same for emails with Email_Status 0 and Email_Status 1.
# * Alternate Hypothesis (H1): The average Word_Count is different for emails with Email_Status 0 and Email_Status 1.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Extracting the Word_Count for Email_Status 0 and 1
word_count_status_0 = df[df['Email_Status'] == 0]['Word_Count']
word_count_status_1 = df[df['Email_Status'] == 1]['Word_Count']

# Perform a two-sample t-test
t_stat, p_value = stats.ttest_ind(word_count_status_0, word_count_status_1, equal_var=False)
print(f'T-Statistic: {t_stat}, P-Value: {p_value}')
# Out:
# T-Statistic: 46.77917908583079, P-Value: 0.0

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# * We performed a two-sample t-test to compare the means of Word_Count between emails with Email_Status 0 and Email_Status 1.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# * The two-sample t-test is used to compare the means between two independent groups to determine if there is a significant difference. In this case, it helps assess if Word_Count differs significantly between the two email statuses.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Filling missing values for numerical columns with mean
df['Total_Past_Communications'].fillna(df['Total_Past_Communications'].mean(), inplace=True)
df['Total_Links'].fillna(df['Total_Links'].mean(), inplace=True)
df['Total_Images'].fillna(df['Total_Images'].mean(), inplace=True)

# Filling missing values for categorical columns with mode (if necessary)
df['Customer_Location_B'].fillna(df['Customer_Location_B'].mode()[0], inplace=True)
df['Customer_Location_C'].fillna(df['Customer_Location_C'].mode()[0], inplace=True)
df['Customer_Location_D'].fillna(df['Customer_Location_D'].mode()[0], inplace=True)
df['Customer_Location_E'].fillna(df['Customer_Location_E'].mode()[0], inplace=True)
df['Customer_Location_F'].fillna(df['Customer_Location_F'].mode()[0], inplace=True)
df['Customer_Location_G'].fillna(df['Customer_Location_G'].mode()[0], inplace=True)

print(df.isnull().sum())
# Out:
# Email_Type                         0
# Subject_Hotness_Score              0
# Email_Source_Type                  0
# Email_Campaign_Type                0
# Total_Past_Communications          0
# Time_Email_sent_Category           0
# Word_Count                         0
# Total_Links                        0
# Total_Images                       0
# Email_Status                       0
# Customer_Location_B                0
# Customer_Location_C                0
# Customer_Location_D                0
# Customer_Location_E                0
# Customer_Location_F                0
# Customer_Location_G                0
# Email_Length_Category_Medium       0
# Email_Length_Category_Long         0
# Email_Length_Category_Very Long    0
# dtype: int64

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# * For numerical columns, the mean is used to impute missing values, which is appropriate as it maintains the central tendency of the data.
#
# * For categorical columns, the mode is used because it represents the most common value and is suitable for categorical data.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

def cap_outliers(df, column):
    upper_limit = df[column].mean() + 3*df[column].std()
    lower_limit = df[column].mean() - 3*df[column].std()
    df[column] = np.where(df[column] > upper_limit, upper_limit, df[column])
    df[column] = np.where(df[column] < lower_limit, lower_limit, df[column])

cap_outliers(df, 'Total_Past_Communications')
cap_outliers(df, 'Total_Links')
cap_outliers(df, 'Total_Images')

print(df.describe())
# Out:
#        Subject_Hotness_Score  Total_Past_Communications    Word_Count  \
# count           68353.000000               68353.000000  68353.000000
# mean                1.095481                  28.932386    699.931751
# std                 0.997578                  11.891523    271.719440
# min                 0.000000                   0.000000     40.000000
# 25%                 0.200000                  20.000000    521.000000
# 50%                 0.800000                  28.933250    694.000000
# 75%                 1.800000                  37.000000    880.000000
# max                 5.000000                  64.615763   1316.000000
#
#         Total_Links  Total_Images  Email_Status
# count  68353.000000  68353.000000  68353.000000
# mean      10.359486      3.446758      0.230934
# std        6.021461      5.117110      0.497032
# min        1.000000      0.000000      0.000000
# 25%        6.000000      0.000000      0.000000
# ...

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# * Capping is used to limit extreme values by setting an upper and lower bound based on the mean and standard deviation, which helps to reduce the impact of outliers without removing data.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

df = pd.get_dummies(df, columns=[
    'Email_Type', 'Email_Source_Type', 'Email_Campaign_Type',
    'Customer_Location_B', 'Customer_Location_C', 'Customer_Location_D',
    'Customer_Location_E', 'Customer_Location_F', 'Customer_Location_G',
    'Email_Length_Category_Medium', 'Email_Length_Category_Long',
    'Email_Length_Category_Very Long'], drop_first=True)

print(df.head())
# Out:
#    Subject_Hotness_Score  Total_Past_Communications Time_Email_sent_Category  \
# 0                    2.2                       33.0                        1
# 1                    2.1                       15.0                        2
# 2                    0.1                       36.0                        2
# 3                    3.0                       25.0                        2
# 4                    0.0                       18.0                        2
#
#    Word_Count  Total_Links  Total_Images  Email_Status  Email_Type_2  \
# 0         440          8.0           0.0             0         False
# 1         504          5.0           0.0             0          True
# 2         962          5.0           0.0             1          True
# 3         610         16.0           0.0             0         False
# 4         947          4.0           0.0             0         False
#
#    Email_Source_Type_2  Email_Campaign_Type_2  Email_Campaign_Type_3  \
# ...

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# * One-Hot Encoding is used to convert categorical variables into binary vectors. It avoids any ordinal relationship and is suitable for nominal categorical data.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# Creating a new feature combining Total_Links and Total_Images
df['Total_Media'] = df['Total_Links'] + df['Total_Images']
print(df.head())
# Out:
#    Subject_Hotness_Score  Total_Past_Communications Time_Email_sent_Category  \
# 0                    2.2                       33.0                        1
# 1                    2.1                       15.0                        2
# 2                    0.1                       36.0                        2
# 3                    3.0                       25.0                        2
# 4                    0.0                       18.0                        2
#
#    Word_Count  Total_Links  Total_Images  Email_Status  Email_Type_2  \
# 0         440          8.0           0.0             0         False
# 1         504          5.0           0.0             0          True
# 2         962          5.0           0.0             1          True
# 3         610         16.0           0.0             0         False
# 4         947          4.0           0.0             0         False
#
#    Email_Source_Type_2  Email_Campaign_Type_2  ...  Customer_Location_B_True  \
# ...

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

from sklearn.feature_selection import SelectKBest, f_classif

# Selecting top 10 features based on ANOVA F-test
X = df.drop('Email_Status', axis=1)
y = df['Email_Status']
selector = SelectKBest(f_classif, k=10)
X_new = selector.fit_transform(X, y)

print(X_new.shape)
# Out:
# (68353, 10)

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# * I used SelectKBest with ANOVA F-test to identify and retain the most significant features that have a strong relationship with the target variable, helping to reduce overfitting.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# * The top features selected are those with the highest F-scores, indicating they are most relevant to predicting the target variable.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %% [markdown]
# * Yes, Power Transformation was used to stabilize variance and make the data more normally distributed, which can help improve the performance of machine learning algorithms.

# %%
# Transform Your data
pt = PowerTransformer()
df_transformed = pt.fit_transform(df)
print(df_transformed.shape)
# Out:
# (68353, 21)

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_transformed)
print(df_scaled.shape)
# Out:
# (68353, 21)

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# * I used StandardScaler to standardize the data to have a mean of 0 and a standard deviation of 1, making it suitable for many machine learning algorithms that assume normally distributed data.

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# * Dimensionality reduction might be needed if your dataset has a large number of features, which can lead to complexity and potential overfitting. If you notice that many features are highly correlated or redundant, reducing dimensionality can help eliminate noise and improve model performance by focusing on the most important features. It can also enhance computational efficiency, making training and prediction faster. Additionally, dimensionality reduction techniques can aid in visualizing high-dimensional data in 2D or 3D, offering insights into its structure and relationships. However, if your dataset is relatively low-dimensional, performs well without issues, and interpretability of features is crucial, dimensionality reduction may not be necessary.

# %%
# Dimensionality Reduction using PCA

pca = PCA(n_components=10)
df_pca = pca.fit_transform(df_scaled)
print(df_pca.shape)
# Out:
# (68353, 10)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# * PCA was chosen to reduce the number of features while retaining the most significant variance in the data, which helps improve model performance and reduce computational complexity.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

X_train, X_test, y_train, y_test = train_test_split(df_pca, df['Email_Status'], test_size=0.3, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (47847, 10) (20506, 10) (47847,) (20506,)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# * The data splitting ratio used is 70% for training and 30% for testing. This ratio was selected to balance the need for a robust model training process and an effective evaluation of model performance. Allocating 70% of the data to the training set ensures that the model has a substantial amount of data to learn from, which is critical for capturing the underlying patterns and relationships within the dataset. The remaining 30% of the data, designated for testing, provides a comprehensive evaluation of the model's generalization capabilities on unseen data. This approach helps in assessing the model's performance metrics reliably and ensures that it is neither overfitting nor underfitting. The 70/30 split is a widely accepted standard in machine learning that offers a practical balance between training and validation, promoting both effective learning and accurate performance assessment.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# * Yes, the dataset is imbalanced. The distribution of the target variable, Email_Status, reveals significant disparities among classes:
#
# Class 0: 54,941 samples
# Class 1: 11,039 samples
# Class 2: 2,373 samples
# This imbalance is evident from the disproportionate number of samples in each class. Class 0, which is the majority class, dominates the dataset, while Classes 1 and 2 are significantly underrepresented.
#
# Such imbalances can lead to several challenges:
#
# Model Bias: Machine learning models may become biased towards the majority class, leading to skewed performance where the model predominantly predicts the majority class. This can adversely affect the predictive accuracy for the minority classes.
#
# Evaluation Metrics: Standard accuracy can be misleading in imbalanced datasets. Metrics such as precision, recall, F1-score, and area under the ROC curve (AUC-ROC) are more informative for assessing model performance on minority classes.
#
# Learning Challenges: The model may struggle to capture the patterns associated with the minority classes due to their limited representation, potentially leading to poor generalization.

# %%
# Handling Imbalanced Dataset (If needed)


smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

print(pd.Series(y_train_resampled).value_counts())
# Out:
# Email_Status
# 0    38436
# 1    38436
# 2    38436
# Name: count, dtype: int64

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# * To address the imbalance in the dataset, I employed the SMOTE (Synthetic Minority Over-sampling Technique) technique. SMOTE is a popular method for handling imbalanced datasets by generating synthetic samples for the minority class.
#
# Reason for Using SMOTE:
# Balancing Class Distribution: SMOTE works by creating synthetic samples in the feature space for the minority class. This process balances the class distribution by increasing the number of samples in the underrepresented classes, which helps in mitigating the bias towards the majority class.
#
# Improving Model Performance: By providing a more balanced dataset, SMOTE helps the model learn better patterns for the minority classes, potentially leading to improved performance metrics such as precision, recall, and F1-score for those classes.
#
# Avoiding Overfitting: Unlike simple oversampling methods that duplicate existing samples, SMOTE generates new, unique samples. This reduces the risk of overfitting that can occur with repeated instances of the same data points.
#
# Enhancing Generalization: With a more balanced training set, the model is better equipped to generalize across all classes, resulting in more reliable predictions and a better understanding of the minority class characteristics.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# Fit the Algorithm
logreg = LogisticRegression(random_state=42, max_iter=1000)
logreg.fit(X_train, y_train)

# Predict on the model
y_pred = logreg.predict(X_test)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
roc_auc = roc_auc_score(y_test, logreg.predict_proba(X_test), multi_class='ovr')

# Visualizing evaluation Metric Score chart
metrics = [accuracy, precision, recall, f1, roc_auc]
metric_names = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC']

plt.figure(figsize=(10, 5))
plt.bar(metric_names, metrics, color='skyblue')
plt.title('Logistic Regression Evaluation Metrics')
plt.xlabel('Metrics')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# Hyperparameter tuning
param_dist = {
    'penalty': ['l1', 'l2', 'elasticnet', 'none'],
    'C': [0.1, 1, 10, 100],
    'solver': ['lbfgs', 'liblinear', 'saga']
}

random_search = RandomizedSearchCV(logreg, param_distributions=param_dist, n_iter=5, cv=3, scoring='roc_auc', random_state=42)
random_search.fit(X_train, y_train)

# Best parameters and performance
best_logreg = random_search.best_estimator_
y_pred_best = best_logreg.predict(X_test)

# Updated Evaluation metrics
accuracy_best = accuracy_score(y_test, y_pred_best)
precision_best = precision_score(y_test, y_pred_best, average='weighted')
recall_best = recall_score(y_test, y_pred_best, average='weighted')
f1_best = f1_score(y_test, y_pred_best, average='weighted')
roc_auc_best = roc_auc_score(y_test, best_logreg.predict_proba(X_test), multi_class='ovr')

# Visualizing evaluation Metric Score chart
metrics_best = [accuracy_best, precision_best, recall_best, f1_best, roc_auc_best]

plt.figure(figsize=(10, 5))
plt.bar(metric_names, metrics_best, color='lightgreen')
plt.title('Optimized Logistic Regression Evaluation Metrics')
plt.xlabel('Metrics')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# * I used RandomizedSearchCV for hyperparameter optimization because it is more efficient than GridSearchCV when dealing with a large hyperparameter space, saving computational time while still exploring a wide range of hyperparameters.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# * The updated metrics show improvements in the model's performance, indicating that hyperparameter tuning was effective.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Fit the Algorithm
gb = GradientBoostingClassifier(random_state=42, n_estimators=100, learning_rate=0.1, max_depth=3)
gb.fit(X_train, y_train)

# Predict on the model
y_pred_gb = gb.predict(X_test)

# Evaluation metrics
accuracy_gb = accuracy_score(y_test, y_pred_gb)
precision_gb = precision_score(y_test, y_pred_gb, average='weighted')
recall_gb = recall_score(y_test, y_pred_gb, average='weighted')
f1_gb = f1_score(y_test, y_pred_gb, average='weighted')
roc_auc_gb = roc_auc_score(y_test, gb.predict_proba(X_test), multi_class='ovr')

# Visualizing evaluation Metric Score chart
metrics_gb = [accuracy_gb, precision_gb, recall_gb, f1_gb, roc_auc_gb]

plt.figure(figsize=(10, 5))
plt.bar(metric_names, metrics_gb, color='skyblue')
plt.title('Gradient Boosting Evaluation Metrics')
plt.xlabel('Metrics')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# Hyperparameter tuning with reduced search space
param_dist_gb = {
    'n_estimators': [50, 100],
    'learning_rate': [0.05, 0.1],
    'max_depth': [3, 4],
}

random_search_gb = RandomizedSearchCV(gb, param_distributions=param_dist_gb, n_iter=5, cv=3, scoring='roc_auc', random_state=42)
random_search_gb.fit(X_train, y_train)

# Best parameters and performance
best_gb = random_search_gb.best_estimator_
y_pred_best_gb = best_gb.predict(X_test)

# Updated Evaluation metrics
accuracy_best_gb = accuracy_score(y_test, y_pred_best_gb)
precision_best_gb = precision_score(y_test, y_pred_best_gb, average='weighted')
recall_best_gb = recall_score(y_test, y_pred_best_gb, average='weighted')
f1_best_gb = f1_score(y_test, y_pred_best_gb, average='weighted')
roc_auc_best_gb = roc_auc_score(y_test, best_gb.predict_proba(X_test), multi_class='ovr')

# Visualizing evaluation Metric Score chart
metrics_best_gb = [accuracy_best_gb, precision_best_gb, recall_best_gb, f1_best_gb, roc_auc_best_gb]

plt.figure(figsize=(10, 5))
plt.bar(metric_names, metrics_best_gb, color='lightgreen')
plt.title('Optimized Gradient Boosting Evaluation Metrics')
plt.xlabel('Metrics')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# * I used RandomizedSearchCV for hyperparameter optimization because it is more efficient than GridSearchCV when dealing with a large hyperparameter space, saving computational time while still exploring a wide range of hyperparameters.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# * The updated metrics show improvements in the model's performance, indicating that hyperparameter tuning was effective.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# Fit the Algorithm
svm = SVC(probability=True, random_state=42)
svm.fit(X_train, y_train)

# Predict on the model
y_pred_svm = svm.predict(X_test)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
# Evaluation metrics
accuracy_svm = accuracy_score(y_test, y_pred_svm)
precision_svm = precision_score(y_test, y_pred_svm, average='weighted')
recall_svm = recall_score(y_test, y_pred_svm, average='weighted')
f1_svm = f1_score(y_test, y_pred_svm, average='weighted')
roc_auc_svm = roc_auc_score(y_test, svm.predict_proba(X_test), multi_class='ovr')

# Visualizing evaluation Metric Score chart
metrics_svm = [accuracy_svm, precision_svm, recall_svm, f1_svm, roc_auc_svm]

plt.figure(figsize=(10, 5))
plt.bar(metric_names, metrics_svm, color='skyblue')
plt.title('SVM Evaluation Metrics')
plt.xlabel('Metrics')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# Reduced hyperparameter tuning
param_dist_svm = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale']
}

random_search_svm = RandomizedSearchCV(svm, param_distributions=param_dist_svm, n_iter=3, cv=3, scoring='roc_auc', random_state=42)
random_search_svm.fit(X_train, y_train)

# Best parameters and performance
best_svm = random_search_svm.best_estimator_
y_pred_best_svm = best_svm.predict(X_test)

# Updated Evaluation metrics
accuracy_best_svm = accuracy_score(y_test, y_pred_best_svm)
precision_best_svm = precision_score(y_test, y_pred_best_svm, average='weighted')
recall_best_svm = recall_score(y_test, y_pred_best_svm, average='weighted')
f1_best_svm = f1_score(y_test, y_pred_best_svm, average='weighted')
roc_auc_best_svm = roc_auc_score(y_test, best_svm.predict_proba(X_test), multi_class='ovr')

# Visualizing evaluation Metric Score chart
metric_names = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC']
metrics_best_svm = [accuracy_best_svm, precision_best_svm, recall_best_svm, f1_best_svm, roc_auc_best_svm]

plt.figure(figsize=(10, 5))
plt.bar(metric_names, metrics_best_svm, color='lightgreen')
plt.title('Optimized SVM Evaluation Metrics')
plt.xlabel('Metrics')
plt.ylabel('Scores')
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# * I used RandomizedSearchCV for hyperparameter optimization because it is more efficient than GridSearchCV when dealing with a large hyperparameter space, saving computational time while still exploring a wide range of hyperparameters.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# * The updated metrics show improvements in the model's performance, indicating that hyperparameter tuning was effective.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# I considered the following evaluation metrics for a positive business impact:
#
# Accuracy: It provides a general overview of the model's performance by showing the proportion of correctly predicted instances. High accuracy indicates that the model is making correct predictions most of the time, which is crucial for maintaining the credibility of the email campaigns.
#
# Precision: Precision is important as it measures the accuracy of positive predictions. In the context of email campaigns, high precision ensures that when the model predicts a successful campaign (positive class), it is likely to be correct. This minimizes the risk of wasting resources on campaigns that are predicted to be successful but actually are not.
#
# Recall: Recall is crucial for identifying actual successful campaigns (true positives). High recall ensures that most of the successful campaigns are identified, reducing the chance of missing out on potential successful email strategies.
#
# F1 Score: The F1 Score is the harmonic mean of precision and recall, providing a balanced view of the model's performance. It is particularly useful when dealing with imbalanced datasets, ensuring that both false positives and false negatives are minimized.
#
# ROC AUC: ROC AUC (Receiver Operating Characteristic Area Under Curve) measures the model's ability to distinguish between classes. A high ROC AUC value indicates that the model is good at distinguishing between successful and unsuccessful campaigns. This is important for making informed decisions on which campaigns to focus on.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# I chose the Gradient Boosting Classifier as the final prediction model.
#
# Reason:
#
# Performance: The Gradient Boosting Classifier showed the highest performance across all evaluation metrics (Accuracy, Precision, Recall, F1 Score, and ROC AUC) after hyperparameter tuning. This indicates that it provides the most balanced and robust predictions.
#
# Feature Importance: Gradient Boosting models provide a clear indication of feature importance, which helps in understanding the factors driving the success of email campaigns. This can be leveraged to optimize future campaigns.
#
# Business Impact: Given its superior performance and ability to identify key features, the Gradient Boosting Classifier is well-suited for making accurate predictions that can positively impact business decisions regarding email marketing strategies.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Model: Gradient Boosting Classifier
#
# Explanation:
#
# Gradient Boosting: Gradient Boosting is an ensemble learning technique that builds multiple decision trees sequentially. Each tree is trained to correct the errors made by the previous trees. This method combines the predictions of multiple weak learners to create a strong predictive model.
# Working: The model starts with an initial prediction and iteratively adds trees to the model. Each new tree is fit on the residual errors of the previous ensemble of trees. The process continues until the desired number of trees is added or the performance improvement becomes negligible.
# Feature Importance:
#
# Tool: SHAP (SHapley Additive exPlanations)
# Usage: SHAP values provide a unified measure of feature importance by distributing the prediction among the features. It explains the contribution of each feature to the final prediction.
# Output: Using SHAP, we can generate a summary plot that shows the impact of each feature on the model's predictions. Features with higher SHAP values are more important for the model's decisions. For instance, features like Total_Past_Communications, Subject_Hotness_Score, and Email_Length_Category might show high importance, indicating their significant role in predicting email campaign success.

# %% [markdown]
# * Conclusion: The Gradient Boosting Classifier, with its high performance and clear feature importance insights provided by SHAP, ensures that we can make informed and accurate predictions about the effectiveness of email campaigns, ultimately leading to better business decisions and optimized resource allocation.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
